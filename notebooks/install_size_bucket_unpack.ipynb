# %%
import pandas as pd
import ast

# %%
tnroof = pd.read_csv('../data/tnroof.csv', dtype={0:'str'})

# %%
tnroof.head()
# Out:
#    region_name state_name    lat_max    lat_min    lng_max    lng_min  \
# 0  47073050700  Tennessee  36.532211  36.363400 -82.610168 -82.933983
# 1  47031980100  Tennessee  35.448120  35.343739 -86.005219 -86.159851
# 2  47187051100  Tennessee  35.874828  35.696449 -86.610909 -86.873047
# 3  47157001100  Tennessee  35.175812  35.160938 -89.933434 -89.953201
# 4  47157001200  Tennessee  35.162498  35.149120 -89.927254 -89.944511
#
#      lat_avg    lng_avg  yearly_sunlight_kwh_kw_threshold_avg  \
# 0  36.446362 -82.762489                               1041.25
# 1  35.391674 -86.067848                               1032.75
# 2  35.778309 -86.749619                               1029.35
# 3  35.167404 -89.941101                               1054.85
# 4  35.155727 -89.935753                               1054.85
#
#    count_qualified  ...  yearly_sunlight_kwh_s  yearly_sunlight_kwh_e  \
# 0                2  ...           8.530174e+03           2.043275e+04
# 1                3  ...           0.000000e+00           0.000000e+00
# 2                8  ...           3.645907e+04           4.432446e+04
# 3              630  ...           1.939470e+06           1.490706e+06
# 4              722  ...           2.003621e+06           1.217512e+06
#
#    yearly_sunlight_kwh_w  yearly_sunlight_kwh_f  yearly_sunlight_kwh_median  \
# 0           0.000000e+00           2.526478e+03                 2526.477661
# 1           1.162019e+03           1.056148e+04                 3597.633301
# 2           4.088778e+04           1.159793e+03                 4918.298389
# 3           8.283687e+05           2.945745e+06                 5813.361670
# 4           1.577554e+06           5.242027e+06                 5949.209973
#
#    yearly_sunlight_kwh_total  \
# 0               3.148940e+04
# 1               1.172350e+04
# 2               1.314785e+05
# 3               7.322225e+06
# 4               1.024544e+07
#
#                              install_size_kw_buckets  \
# 0                                     [[0,1],[25,1]]
# 1                                            [[0,3]]
# 2                 [[0,4],[5,1],[15,1],[20,1],[45,1]]
# 3  [[0,317],[5,210],[10,54],[15,18],[20,1],[25,2]...
# 4  [[0,335],[5,249],[10,71],[15,18],[20,5],[25,9]...
#
#    carbon_offset_metric_tons  existing_installs_count  \
# 0                  24.045846                        0
# 1                   8.952267                        0
# 2                 100.399204                        0
# 3                5591.376756                        1
# 4                7823.597262                        0
#
#                                   center_point
# 0    POINT (-82.7624893188477 36.446361541748)
# 1   POINT (-86.06784820556641 35.391674041748)
# 2  POINT (-86.74961853027339 35.7783088684082)
# 3  POINT (-89.94110107421881 35.1674041748047)
# 4   POINT (-89.9357528686523 35.1557273864746)
#
# [5 rows x 32 columns]

# %%
tnroof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 32 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   region_name                           1030 non-null   object
#  1   state_name                            1030 non-null   object
#  2   lat_max                               1030 non-null   float64
#  3   lat_min                               1030 non-null   float64
#  4   lng_max                               1030 non-null   float64
#  5   lng_min                               1030 non-null   float64
#  6   lat_avg                               1030 non-null   float64
#  7   lng_avg                               1030 non-null   float64
#  8   yearly_sunlight_kwh_kw_threshold_avg  950 non-null    float64
#  9   count_qualified                       1030 non-null   int64
#  10  percent_covered                       1030 non-null   float64
#  11  percent_qualified                     1030 non-null   float64
#  12  number_of_panels_n                    1030 non-null   int64
#  13  number_of_panels_s                    1030 non-null   int64
#  14  number_of_panels_e                    1030 non-null   int64
#  15  number_of_panels_w                    1030 non-null   int64
#  16  number_of_panels_f                    1030 non-null   int64
#  17  number_of_panels_median               1027 non-null   float64
#  18  number_of_panels_total                947 non-null    float64
#  19  kw_median                             1027 non-null   float64
#  20  kw_total                              947 non-null    float64
#  21  yearly_sunlight_kwh_n                 1030 non-null   float64
#  22  yearly_sunlight_kwh_s                 1030 non-null   float64
#  23  yearly_sunlight_kwh_e                 1030 non-null   float64
#  24  yearly_sunlight_kwh_w                 1030 non-null   float64
#  25  yearly_sunlight_kwh_f                 1030 non-null   float64
#  26  yearly_sunlight_kwh_median            1027 non-null   float64
#  27  yearly_sunlight_kwh_total             947 non-null    float64
#  28  install_size_kw_buckets               1027 non-null   object
#  29  carbon_offset_metric_tons             1030 non-null   float64
#  30  existing_installs_count               1030 non-null   int64
#  31  center_point                          1030 non-null   object
# dtypes: float64(21), int64(7), object(4)
# memory usage: 257.6+ KB

# %%
tnroof.install_size_kw_buckets.iloc[0]
# Out:
# '[[0,1],[25,1]]'

# %%
x= tnroof.install_size_kw_buckets.iloc[0]
x
# Out:
# '[[0,1],[25,1]]'

# %%
res = ast.literal_eval(tnroof.install_size_kw_buckets.iloc[0])

# %%
type(res)
# Out:
# list

# %%
def lister(row):
    try:
        res = ast.literal_eval(row.install_size_kw_buckets)
    except:
        res = [[0,0]]
    return res

# %%
tnroof['install_size_kw_buckets'] = tnroof.apply(lambda x: lister(x), axis=1)

# %%
tnroof.install_size_kw_buckets[0]
# Out:
# [[0, 1], [25, 1]]

# %%
tnroof.install_size_kw_buckets[0]
# Out:
# [[0, 1], [25, 1]]

# %%
buckets = pd.DataFrame()
for index, row in tnroof.iterrows():
    bucket = {}
    bucket['region_name'] = row['region_name']
    for buc in row.install_size_kw_buckets:
        if buc[0] > 200:
            bucket['install_size_kw_bucket200+'] = buc[1]
        elif buc[0] > 150:
            bucket['install_size_kw_bucket150-200'] = buc[1]
        elif buc[0] > 100:
            bucket['install_size_kw_bucket100-149'] = buc[1]
        elif buc[0] > 50:
            bucket['install_size_kw_bucket50-99'] = buc[1]  
        else:
            bucket['install_size_kw_bucket' + str(buc[0])] = buc[1]
    buckets = buckets.append(bucket, ignore_index=True)

# %%
buckets
# Out:
#       region_name  install_size_kw_bucket0  install_size_kw_bucket25  \
# 0     47073050700                      1.0                       1.0
# 1     47031980100                      3.0                       NaN
# 2     47187051100                      4.0                       NaN
# 3     47157001100                    317.0                       2.0
# 4     47157001200                    335.0                       9.0
# ...           ...                      ...                       ...
# 1025  47037980100                     35.0                       5.0
# 1026  47157980100                     21.0                      14.0
# 1027  47165021205                     52.0                     107.0
# 1028  47037015900                    126.0                      16.0
# 1029  47093000100                     34.0                       7.0
#
#       install_size_kw_bucket15  install_size_kw_bucket20  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          1.0                       1.0
# 3                         18.0                       1.0
# 4                         18.0                       5.0
# ...                        ...                       ...
# 1025                      11.0                      13.0
# 1026                      17.0                      16.0
# 1027                     318.0                     271.0
# 1028                      44.0                      25.0
# 1029                      28.0                      21.0
#
#       install_size_kw_bucket45  install_size_kw_bucket5  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          1.0                      1.0
# 3                          1.0                    210.0
# 4                          2.0                    249.0
# ...                        ...                      ...
# 1025                       1.0                     26.0
# 1026                      12.0                     22.0
# 1027                       5.0                    151.0
# 1028                       8.0                    165.0
# 1029                      12.0                     48.0
#
#       install_size_kw_bucket10  install_size_kw_bucket100-149  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                         54.0                            1.0
# 4                         71.0                            1.0
# ...                        ...                            ...
# 1025                      11.0                            1.0
# 1026                      30.0                            5.0
# 1027                     272.0                            1.0
# 1028                      77.0                            2.0
# 1029                      34.0                            2.0
#
#       install_size_kw_bucket200+  install_size_kw_bucket30  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            1.0                       4.0
# 4                            1.0                       3.0
# ...                          ...                       ...
# 1025                         1.0                       5.0
# 1026                         1.0                      12.0
# 1027                         1.0                      42.0
# 1028                         1.0                      16.0
# 1029                         1.0                      13.0
#
#       install_size_kw_bucket35  install_size_kw_bucket50-99  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          4.0                          2.0
# 4                          1.0                          1.0
# ...                        ...                          ...
# 1025                       7.0                          1.0
# 1026                      15.0                          4.0
# 1027                      25.0                          1.0
# 1028                      18.0                          8.0
# 1029                      19.0                          5.0
#
#       install_size_kw_bucket150-200  install_size_kw_bucket40  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               1.0                       3.0
# ...                             ...                       ...
# 1025                            1.0                       9.0
# 1026                            3.0                      11.0
# 1027                            2.0                      10.0
# 1028                            6.0                      17.0
# 1029                            2.0                      10.0
#
#       install_size_kw_bucket50
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          1.0
# ...                        ...
# 1025                       3.0
# 1026                       7.0
# 1027                       2.0
# 1028                      22.0
# 1029                       9.0
#
# [1030 rows x 16 columns]
