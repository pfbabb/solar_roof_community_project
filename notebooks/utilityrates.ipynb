# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
utilities = pd.read_csv('../data/utilities.csv',index_col=0, na_values='No', dtype={'GEOID10':'str','eiaid':'str'})
ratesdict = pd.read_excel('../data/rates19/Sales_Ult_Cust_2019.xlsx',
                      sheet_name=['States','Territories'], header=2,usecols='B:E,G:H,K:M', dtype={'Utility Number':'str'}, na_values='.')
rates = pd.concat([df for df in ratesdict.values()], ignore_index=True)
metros = gpd.read_file('../data/metro/tl_2020_us_uac10.shp')
print(rates.info())
print(utilities.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Utility Number    4498 non-null   object
#  1   Utility Name      4498 non-null   object
#  2   Part              4498 non-null   object
#  3   Service Type      4498 non-null   object
#  4   State             4498 non-null   object
#  5   Ownership         4364 non-null   object
#  6   Thousand Dollars  4373 non-null   float64
#  7   Megawatthours     4372 non-null   float64
#  8   Count             4373 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 316.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 17423 entries, 0.0 to nan
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   GEOID10  16635 non-null  object
#  1   utility  15059 non-null  object
#  2   eiaid    15046 non-null  object
# dtypes: object(3)
# memory usage: 544.5+ KB
# None

# %%
#average of top 12 largest retail providers for TX
txrates = rates[(rates['State']=='TX')&(rates['Ownership']=='Retail Power Marketer')].nlargest(n=12,columns='Count').mean(numeric_only=True).to_dict()
txrates['Utility Name'] = 'TX Average'
rates = rates[rates['Megawatthours']>0]
#will calulate again later down the road
#rates['rate'] = rates['Thousand Dollars'] / rates['Megawatthours']
#rates['usage'] = rates['Megawatthours'] / rates['Count']
rates.head()
# Out:
#   Utility Number              Utility Name Part Service Type State  \
# 0             34  City of Abbeville - (SC)    A      Bundled    SC
# 1             55   City of Aberdeen - (MS)    A      Bundled    MS
# 2             59  City of Abbeville - (LA)    A      Bundled    LA
# 3             84       A & N Electric Coop    A      Bundled    MD
# 4             84       A & N Electric Coop    A      Bundled    VA
#
#      Ownership  Thousand Dollars  Megawatthours    Count
# 0    Municipal            4563.0        33000.0   3384.0
# 1    Municipal            3930.0        34781.0   2566.0
# 2    Municipal            5907.5        59232.0   4580.0
# 3  Cooperative             273.5         2094.0    272.0
# 4  Cooperative           44102.0       357988.0  31427.0

# %%
states = []
for index, row in metros.iterrows():
    states.append(metros.loc[index,'NAME10'].split(',')[1][1:3])
metros['State'] = states
metros.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3601 entries, 0 to 3600
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UACE10      3601 non-null   object
#  1   GEOID10     3601 non-null   object
#  2   NAME10      3601 non-null   object
#  3   NAMELSAD10  3601 non-null   object
#  4   LSAD10      3601 non-null   object
#  5   MTFCC10     3601 non-null   object
#  6   UATYP10     3601 non-null   object
#  7   FUNCSTAT10  3601 non-null   object
#  8   ALAND10     3601 non-null   int64
#  9   AWATER10    3601 non-null   int64
#  10  INTPTLAT10  3601 non-null   object
#  11  INTPTLON10  3601 non-null   object
#  12  geometry    3601 non-null   geometry
#  13  State       3601 non-null   object
# dtypes: geometry(1), int64(2), object(11)
# memory usage: 394.0+ KB

# %%
prdf = pd.DataFrame({'GEOID10':metros[metros['State']=='PR']['GEOID10'].to_list()})
prdf['utility'] = 'PR Power'  
prdf['eiaid'] = '15497'
utilities = utilities.append(prdf)

# %%
utilities = utilities.dropna(subset=['GEOID10'])
utilities.GEOID10 = utilities.GEOID10.apply(lambda x: x.split('.',1)[0].zfill(5))
utilities = utilities.dropna(subset=['GEOID10']).dropna(subset=['eiaid']).drop_duplicates()
utilities
# Out:
#      GEOID10                                            utility  eiaid
# 0.0    24310                             Commonwealth Edison Co   4110
# 1.0    27847       City of Escanaba, Michigan (Utility Company)  24558
# 2.0    18100  City of Clintonville, Wisconsin (Utility Company)   3814
# 3.0    06166                            Duke Energy Indiana Inc  15470
# 4.0    75270                          Pacific Gas & Electric Co  14328
# ...      ...                                                ...    ...
# 14.0   70642                                           PR Power  15497
# 15.0   28981                                           PR Power  15497
# 16.0   97561                                           PR Power  15497
# 17.0   03034                                           PR Power  15497
# 18.0   78985                                           PR Power  15497
#
# [5061 rows x 3 columns]

# %%
utilities.GEOID10.value_counts()
# Out:
# 76339    8
# 55981    8
# 94591    8
# 01819    8
# 88504    8
#         ..
# 82198    1
# 61867    1
# 53200    1
# 96350    1
# 78985    1
# Name: GEOID10, Length: 3255, dtype: int64

# %%
ratemerge = rates.merge(utilities, left_on='Utility Number', right_on='eiaid', how='inner').drop(columns=['utility'])

ratemerge
# Out:
#       Utility Number                        Utility Name Part Service Type  \
# 0                 34            City of Abbeville - (SC)    A      Bundled
# 1                 55             City of Aberdeen - (MS)    A      Bundled
# 2                123                  City of Adel- (GA)    A      Bundled
# 3                176                  Ajo Improvement Co    A      Bundled
# 4                183             Village of Akron - (NY)    A      Bundled
# ...              ...                                 ...  ...          ...
# 10318          15497  Puerto Rico Electric Pwr Authority    A      Bundled
# 10319          15497  Puerto Rico Electric Pwr Authority    A      Bundled
# 10320          15497  Puerto Rico Electric Pwr Authority    A      Bundled
# 10321          15497  Puerto Rico Electric Pwr Authority    A      Bundled
# 10322          15497  Puerto Rico Electric Pwr Authority    A      Bundled
#
#       State       Ownership  Thousand Dollars  Megawatthours      Count  \
# 0        SC       Municipal            4563.0        33000.0     3384.0
# 1        MS       Municipal            3930.0        34781.0     2566.0
# 2        GA       Municipal            3988.0        27905.0     2080.0
# 3        AZ  Investor Owned             502.7         4717.0      799.0
# 4        NY       Municipal             954.0        18267.0     1442.0
# ...     ...             ...               ...            ...        ...
# 10318    PR           State         1314886.0      6134900.0  1341424.0
# 10319    PR           State         1314886.0      6134900.0  1341424.0
# 10320    PR           State         1314886.0      6134900.0  1341424.0
# 10321    PR           State         1314886.0      6134900.0  1341424.0
# 10322    PR           State         1314886.0      6134900.0  1341424.0
#
#       GEOID10  eiaid
# 0       00064     34
# 1       00118     55
# 2       00469    123
# 3       00712    176
# 4       00739    183
# ...       ...    ...
# 10318   70642  15497
# 10319   28981  15497
# 10320   97561  15497
# 10321   03034  15497
# 10322   78985  15497
#
# [10323 rows x 11 columns]

# %%
ratemerge.GEOID10.value_counts()
# Out:
# 55981    42
# 45505    42
# 01819    42
# 76339    42
# 88504    42
#          ..
# 56872     1
# 96926     1
# 60733     1
# 28954     1
# 78985     1
# Name: GEOID10, Length: 3216, dtype: int64

# %%
metromerge = metros.merge(ratemerge, how='left', left_on=['GEOID10', 'State'], right_on=['GEOID10', 'State'])
for index, row in metromerge[(metromerge['State']=='TX')&metromerge['Count'].isna()].iterrows():
    for key, value in txrates.items():
        metromerge.at[index, key] = value
metromerge
# Out:
#      UACE10 GEOID10                       NAME10  \
# 0     24310   24310                    Dixon, IL
# 1     24310   24310                    Dixon, IL
# 2     27847   27847                 Escanaba, MI
# 3     18100   18100             Clintonville, WI
# 4     06166   06166                  Bedford, IN
# ...     ...     ...                          ...
# 5989  10675   10675                 Brooklyn, MI
# 5990  31450   31450  Franklin--Highland Lake, NJ
# 5991  31450   31450  Franklin--Highland Lake, NJ
# 5992  16171   16171                  Chester, NY
# 5993  16171   16171                  Chester, NY
#
#                                      NAMELSAD10 LSAD10 MTFCC10 UATYP10  \
# 0                       Dixon, IL Urban Cluster     76   G3500       C
# 1                       Dixon, IL Urban Cluster     76   G3500       C
# 2                    Escanaba, MI Urban Cluster     76   G3500       C
# 3                Clintonville, WI Urban Cluster     76   G3500       C
# 4                     Bedford, IN Urban Cluster     76   G3500       C
# ...                                         ...    ...     ...     ...
# 5989                 Brooklyn, MI Urban Cluster     76   G3500       C
# 5990  Franklin--Highland Lake, NJ Urban Cluster     76   G3500       C
# 5991  Franklin--Highland Lake, NJ Urban Cluster     76   G3500       C
# 5992                  Chester, NY Urban Cluster     76   G3500       C
# 5993                  Chester, NY Urban Cluster     76   G3500       C
#
#      FUNCSTAT10   ALAND10  AWATER10  ... State Utility Number  \
# 0             S  25562730    938057  ...    IL           4110
# 1             S  25562730    938057  ...    IL           4110
# 2             S  46643391    283456  ...    MI          24558
# 3             S   5854687    502563  ...    WI           3814
# 4             S  30413950      2314  ...    IN          15470
# ...         ...       ...       ...  ...   ...            ...
# 5989          S   7677057    129296  ...    MI           4254
# 5990          S  84306618   3337407  ...    NJ           9726
# 5991          S  84306618   3337407  ...    NJ           9726
# 5992          S   9360430      3420  ...    NY          14154
# 5993          S   9360430      3420  ...    NY          14154
#
#                       Utility Name Part Service Type       Ownership  \
# 0           Commonwealth Edison Co    A      Bundled  Investor Owned
# 1           Commonwealth Edison Co    C     Delivery  Investor Owned
# 2                 City of Escanaba    A      Bundled       Municipal
# 3      City of Clintonville - (WI)    A      Bundled       Municipal
# 4         Duke Energy Indiana, LLC    A      Bundled  Investor Owned
# ...                            ...  ...          ...             ...
# 5989           Consumers Energy Co    A      Bundled  Investor Owned
# 5990  Jersey Central Power & Lt Co    A      Bundled  Investor Owned
# 5991  Jersey Central Power & Lt Co    C     Delivery  Investor Owned
# 5992   Orange & Rockland Utils Inc    A      Bundled  Investor Owned
# 5993   Orange & Rockland Utils Inc    C     Delivery  Investor Owned
#
#      Thousand Dollars Megawatthours      Count  eiaid
# 0           2343491.1    17616341.0  2520161.0   4110
# 1            572201.4     9196718.0  1137735.0   4110
# 2              4337.0       34913.0     6037.0  24558
# 3              1941.0       17689.0     2342.0   3814
# 4           1085020.7     9246749.0   733944.0  15470
# ...               ...           ...        ...    ...
# 5989        1978868.2    12484700.0  1611320.0   4254
# 5990        1023079.7     7788851.0   842987.0   9726
# 5991          69792.9     1633991.0   163562.0   9726
# 5992         201414.8     1037927.0   141580.0  14154
# 5993          68630.5      577965.0    61498.0  14154
#
# [5994 rows x 23 columns]

# %%
metromerge.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5994 entries, 0 to 5993
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UACE10            5994 non-null   object
#  1   GEOID10           5994 non-null   object
#  2   NAME10            5994 non-null   object
#  3   NAMELSAD10        5994 non-null   object
#  4   LSAD10            5994 non-null   object
#  5   MTFCC10           5994 non-null   object
#  6   UATYP10           5994 non-null   object
#  7   FUNCSTAT10        5994 non-null   object
#  8   ALAND10           5994 non-null   int64
#  9   AWATER10          5994 non-null   int64
#  10  INTPTLAT10        5994 non-null   object
#  11  INTPTLON10        5994 non-null   object
#  12  geometry          5994 non-null   geometry
#  13  State             5994 non-null   object
#  14  Utility Number    5585 non-null   object
#  15  Utility Name      5741 non-null   object
#  16  Part              5585 non-null   object
#  17  Service Type      5585 non-null   object
#  18  Ownership         5585 non-null   object
#  19  Thousand Dollars  5741 non-null   float64
#  20  Megawatthours     5741 non-null   float64
#  21  Count             5741 non-null   float64
#  22  eiaid             5585 non-null   object
# dtypes: float64(3), geometry(1), int64(2), object(17)
# memory usage: 1.2+ MB

# %%
metromap = metromerge.sort_values('Count', ascending=False).drop_duplicates(subset='GEOID10', keep='first')
#[metromerge['rate'].isnull()]
#.dropna(subset=['Count'])
metromap
# Out:
#      UACE10 GEOID10                          NAME10  \
# 3653  79606   79606         Sarasota--Bradenton, FL
# 897   67051   67051                     Palatka, FL
# 908   50500   50500                    Live Oak, FL
# 4025  02912   02912  Arcadia--Southeast Arcadia, FL
# 1411  56602   56602                       Miami, FL
# ...     ...     ...                             ...
# 5837  29116   29116                   Faribault, MN
# 5909  02440   02440                     Andrews, SC
# 5912  07894   07894                 Bishopville, SC
# 5913  11566   11566                      Burgaw, NC
# 5947  30898   30898                  Fort Scott, KS
#
#                                         NAMELSAD10 LSAD10 MTFCC10 UATYP10  \
# 3653        Sarasota--Bradenton, FL Urbanized Area     75   G3500       U
# 897                      Palatka, FL Urban Cluster     76   G3500       C
# 908                     Live Oak, FL Urban Cluster     76   G3500       C
# 4025  Arcadia--Southeast Arcadia, FL Urban Cluster     76   G3500       C
# 1411                      Miami, FL Urbanized Area     75   G3500       U
# ...                                            ...    ...     ...     ...
# 5837                   Faribault, MN Urban Cluster     76   G3500       C
# 5909                     Andrews, SC Urban Cluster     76   G3500       C
# 5912                 Bishopville, SC Urban Cluster     76   G3500       C
# 5913                      Burgaw, NC Urban Cluster     76   G3500       C
# 5947                  Fort Scott, KS Urban Cluster     76   G3500       C
#
#      FUNCSTAT10     ALAND10   AWATER10  ... State Utility Number  \
# 3653          S   844389439  107188680  ...    FL           6452
# 897           S    58715239     449791  ...    FL           6452
# 908           S    14498690       3873  ...    FL           6452
# 4025          S    26177161      15770  ...    FL           6452
# 1411          S  3177138995  222863436  ...    FL           6452
# ...         ...         ...        ...  ...   ...            ...
# 5837          S    29469201     592057  ...    MN            NaN
# 5909          S     7781113          0  ...    SC            NaN
# 5912          S     5967255          0  ...    SC            NaN
# 5913          S     6407466          0  ...    NC            NaN
# 5947          S    10836985      12152  ...    KS            NaN
#
#                   Utility Name Part Service Type       Ownership  \
# 3653  Florida Power & Light Co    A      Bundled  Investor Owned
# 897   Florida Power & Light Co    A      Bundled  Investor Owned
# 908   Florida Power & Light Co    A      Bundled  Investor Owned
# 4025  Florida Power & Light Co    A      Bundled  Investor Owned
# 1411  Florida Power & Light Co    A      Bundled  Investor Owned
# ...                        ...  ...          ...             ...
# 5837                       NaN  NaN          NaN             NaN
# 5909                       NaN  NaN          NaN             NaN
# 5912                       NaN  NaN          NaN             NaN
# 5913                       NaN  NaN          NaN             NaN
# 5947                       NaN  NaN          NaN             NaN
#
#      Thousand Dollars Megawatthours      Count  eiaid
# 3653        6655476.0    60338973.0  4479356.0   6452
# 897         6655476.0    60338973.0  4479356.0   6452
# 908         6655476.0    60338973.0  4479356.0   6452
# 4025        6655476.0    60338973.0  4479356.0   6452
# 1411        6655476.0    60338973.0  4479356.0   6452
# ...               ...           ...        ...    ...
# 5837              NaN           NaN        NaN    NaN
# 5909              NaN           NaN        NaN    NaN
# 5912              NaN           NaN        NaN    NaN
# 5913              NaN           NaN        NaN    NaN
# 5947              NaN           NaN        NaN    NaN
#
# [3601 rows x 23 columns]

# %%
center = metromerge[metromerge.GEOID10 == '30898'].geometry.centroid
area_center = [center.y, center.x]
print(area_center)
# Out:
# [5947    37.829925
# dtype: float64, 5947   -94.703396
# dtype: float64]
# <ipython-input-13-40655cbfbb46>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = metromerge[metromerge.GEOID10 == '30898'].geometry.centroid

# %%
testmap = folium.Map(location = area_center, zoom_start = 4)

marker_cluster = MarkerCluster().add_to(testmap)

#folium.GeoJson(metromap).add_to(testmap)

# folium.Choropleth(
#     geo_data=metromap,
#     data=metromap,
#     columns=['GEOID10','ALAND10'],
#     key_on='feature.properties.GEOID10',
#     fill_color='YlOrRd',
#     fill_opacity=0.7,
#     line_opacity=0.5,
#     bins=8
#              ).add_to(testmap)

for row_i, row_val in metromap.iterrows():
    center = row_val.geometry.centroid
    loc = [center.y,center.x]
    pop = str(row_val['NAMELSAD10']) + str(" - ") + str(row_val['GEOID10']) + str(' - ') + str(row_val['Count']) 
    if row_val['Count'] > 0:
        icon = folium.Icon(icon='hand-scissors-o', prefix='fa', color='green')
    else:
        icon = folium.Icon(icon='hand-scissors-o', prefix='fa', color='red')
    
    marker = folium.Marker(
        location = loc,
        popup = pop,
        icon = icon)
    marker.add_to(marker_cluster)
    
testmap.save('../data/testmap.html')

# %%
metromerge[(~(metromerge['State']=='PR'))&(metromerge['Count'].isna())].nlargest(n=50,columns='ALAND10').iloc[:,1:3]
# Out:
#      GEOID10                            NAME10
# 2410   22811     Dededo--Machanao--Apotgan, GU
# 4336   61840                      New Bern, NC
# 5819   69517     Pinehurst--Southern Pines, NC
# 2414   16750                 Christiansted, VI
# 3879   69778                    Pittsfield, MA
# 3313   93862                     Wenatchee, WA
# 4520   30171                         Foley, AL
# 3332   22204                      Danville, IL
# 5713   48691                       Lebanon, TN
# 210    78877                       Sanford, NC
# 2416   86369                        Tafuna, AS
# 5147   34219               Grand Forks, ND--MN
# 2413   15697        Charlotte Amalie--Tutu, VI
# 3494   73045                        Quincy, IL
# 3638   82522                    Smithfield, NC
# 2412   32506               Garapan--Dandan, MP
# 4673   57655                         Minot, ND
# 2378   32329                     Galesburg, IL
# 3218   48728          Lebanon--Hanover, NH--VT
# 4347   02965         Archer Lodge--Clayton, NC
# 5752   13267                    Cañon City, CO
# 5813   48178                    Laurinburg, NC
# 4332   38269                     Henderson, NC
# 1915   54486                  Marietta, OH--WV
# 2389   41671  Iron Mountain--Kingsford, MI--WI
# 2212   16453                   Chillicothe, OH
# 2804   83305          South Lake Tahoe, CA--NV
# 820    25309                     Dyersburg, TN
# 4394   07508                 Big Bear City, CA
# 5820   36585                     Hampstead, NC
# 2360   34975                    Greenfield, MA
# 4658   37675                      Havelock, NC
# 934    44182                       Kearney, NE
# 136    00145                      Aberdeen, SD
# 221    37405                    Hartsville, SC
# 4251   63406                       Norfolk, NE
# 186    64459                    Oak Island, NC
# 4103   15022                     Centralia, IL
# 5611   66295                        Ottawa, IL
# 467    69643                     Pittsburg, KS
# 2757   42373                  Jacksonville, IL
# 5837   29116                     Faribault, MN
# 3878   48745                           Lee, MA
# 4356   25039                          Dunn, NC
# 1512   90703                     Vincennes, IN
# 3323   60328                  Mount Vernon, IL
# 5171   55576                       Mattoon, IL
# 603    71209               Port Jervis, NY--PA
# 4429   11134                       Buckeye, AZ
# 4393   61435                   Needles, CA--AZ

# %%
metromap.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 3601 entries, 3653 to 5947
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UACE10            3601 non-null   object
#  1   GEOID10           3601 non-null   object
#  2   NAME10            3601 non-null   object
#  3   NAMELSAD10        3601 non-null   object
#  4   LSAD10            3601 non-null   object
#  5   MTFCC10           3601 non-null   object
#  6   UATYP10           3601 non-null   object
#  7   FUNCSTAT10        3601 non-null   object
#  8   ALAND10           3601 non-null   int64
#  9   AWATER10          3601 non-null   int64
#  10  INTPTLAT10        3601 non-null   object
#  11  INTPTLON10        3601 non-null   object
#  12  geometry          3601 non-null   geometry
#  13  State             3601 non-null   object
#  14  Utility Number    3192 non-null   object
#  15  Utility Name      3348 non-null   object
#  16  Part              3192 non-null   object
#  17  Service Type      3192 non-null   object
#  18  Ownership         3192 non-null   object
#  19  Thousand Dollars  3348 non-null   float64
#  20  Megawatthours     3348 non-null   float64
#  21  Count             3348 non-null   float64
#  22  eiaid             3192 non-null   object
# dtypes: float64(3), geometry(1), int64(2), object(17)
# memory usage: 675.2+ KB

# %%
metromap.to_file('../data/ratesbymetro.geojson', driver='GeoJSON')

# %%
metromap.drop(columns=['geometry','LSAD10','MTFCC10','UATYP10','FUNCSTAT10']).to_csv('../data/ratesbymetro.csv', index=False)
